# %% [raw]
# ---
# title: "Verband der Ärztinnen und Ärzte des Öffentlichen Gesundheitsdienstes der Länder Brandenburg und Berlin e.V."
# toc: false
# ---

# %% [markdown]
# ```{css, echo=FALSE}
# .title {
#   font-size: 100px;
#   font-style: italic;
#   color: blue;
#   font-family: Arial;
#   font-variant: small-caps;
# }
# ```
#
#
#
# ![](img/logo.png){fig-align="center"}
#
# Wir sind der Verband der Ärztinnen und Ärzte des Öffentlichen Gesundheitsdienstes der Länder Brandenburg und Berlin e.V.! In diesem Verband engagieren wir uns ehrenamtlich.  Wir vertreten die Interessen der Mitglieder, der Interessen anderer Beschätigter im Öffentlichen Gesundheitsdienst Mitarbeitenden und die Interessen der Bürgerinnen und Bürger.
#
#
# ### Das sind wir
# :::: {.columns}
# ::: {.column width="25%"}
# <center>
#
# {{< iconify healthicons doctor-female size=5x >}}
#
#
# </center>
# :::
# ::: {.column width="75%"}
# * Ärztinnen und Ärzte im Öffentlichen Gesundheitsdienst
# * Ehrenamtliche Tätige
#
# :::
# ::::
#
#
# ### Das tun wir
# :::: {.columns}
# ::: {.column width="25%"}
# <center>
# {{< iconify healthicons intensity-concentration-bioassays-outline size=5x >}}</center>
# </center>
# :::
# ::: {.column width="75%"}
# * Vertretung der Mitglieder
# * Förderung der öffentlichen Gesundheit
# * Forderungen der öffentlichen Gesundheit
# * Austausch
# * Fortbildung
# * Beratung
# :::
# ::::
#
#
#
# ### Da wollen wir hin
# :::: {.columns}
# ::: {.column width="25%"}
# <center>
# {{< iconify healthicons happy size=5x >}}</center>
# </center>
# :::
# ::: {.column width="75%"}
# * Gesunde Bevölkerung
# * Biologische, psychische und soziale Gesundheit
# * Starke und stablie Gesundheitsämter
# :::
# ::::
